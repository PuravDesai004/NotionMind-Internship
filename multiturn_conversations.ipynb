# %%
from anthropic import Anthropic
from dotenv import load_dotenv
import os

load_dotenv()
api_key=os.getenv("ANTHROPIC_API_KEY")
client=Anthropic(api_key=api_key)
model="claude-haiku-4-5-20251001"

def add_user_message(messages,text):
    messages.append({"role":"user","content":text})

def add_assistant_message(messages,text):
    messages.append({"role":"assistant","content":text})

def chat(messages):
    res=client.messages.create(
        model=model,
        max_tokens=100,
        messages=messages
    )
    return res.content[0].text

messages = [] 

while True:
    user_ip=input(">>")
    print(">>",user_ip)
    
    add_user_message(messages,user_ip)
    claude_res=chat(messages)
    
    add_assistant_message(messages,claude_res)
    
    print("---------------")
    print(claude_res)
    print("---------------")
# Out:
# >> whos messi?
# ---------------
# # Lionel Messi
#
# Lionel Messi is an Argentine professional footballer, widely considered one of the greatest players of all time. Here are the key points:
#
# **Career highlights:**
# - Played most of his career for FC Barcelona (2004-2021)
# - Joined Paris Saint-Germain (2021-2023)
# - Currently plays for Inter Miami CF (MLS)
#
# **Achievements:**
# - Won the FIFA World
# ---------------
# >> is he the goat?
# ---------------
# # Is Messi the GOAT?
#
# It's debatable, but he has a strong case:
#
# **Arguments for Messi as GOAT:**
# - 8 Ballon d'Or awards (most ever)
# - Won the 2022 FIFA World Cup with Argentina
# - Incredible consistency over 2 decades
# - Exceptional dribbling, vision, and finishing
#
# **Arguments against:**
# - Some argue Pelé or Diego
# ---------------
# >>
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[1], line 31
#      27     user_ip=input(">>")
#      28     print(">>",user_ip)
#      29
#      30     add_user_message(messages,user_ip)
# ---> 31     claude_res=chat(messages)
#      32
#      33     add_assistant_message(messages,claude_res)
#      34
#
# Cell In[1], line 17, in chat(messages)
#      16 def chat(messages):
# ---> 17     res=client.messages.create(
#      18         model=model,
#      19         max_tokens=100,
#      20         messages=messages
#
# File c:\Users\purav\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_utils\_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File c:\Users\purav\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\resources\messages\messages.py:1009, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#    1002 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#    1003     warnings.warn(
#    1004         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1005         UserWarning,
#    1006         stacklevel=3,
#    1007     )
# -> 1009 return self._post(
#    1010     "/v1/messages",
#    1011     body=maybe_transform(
#    1012         {
#    1013             "max_tokens": max_tokens,
#    1014             "messages": messages,
#    1015             "model": model,
#    1016             "cache_control": cache_control,
#    1017             "container": container,
#    1018             "inference_geo": inference_geo,
#    1019             "metadata": metadata,
#    1020             "output_config": output_config,
#    1021             "service_tier": service_tier,
#    1022             "stop_sequences": stop_sequences,
#    1023             "stream": stream,
#    1024             "system": system,
#    1025             "temperature": temperature,
#    1026             "thinking": thinking,
#    1027             "tool_choice": tool_choice,
#    1028             "tools": tools,
#    1029             "top_k": top_k,
#    1030             "top_p": top_p,
#    1031         },
#    1032         message_create_params.MessageCreateParamsStreaming
#    1033         if stream
#    1034         else message_create_params.MessageCreateParamsNonStreaming,
#    1035     ),
#    1036     options=make_request_options(
#    1037         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1038     ),
#    1039     cast_to=Message,
#    1040     stream=stream or False,
#    1041     stream_cls=Stream[RawMessageStreamEvent],
#    1042 )
#
# File c:\Users\purav\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_base_client.py:1535, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1526     warnings.warn(
#    1527         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1528         "Please pass raw bytes via the `content` parameter instead.",
#    1529         DeprecationWarning,
#    1530         stacklevel=2,
#    1531     )
#    1532 opts = FinalRequestOptions.construct(
#    1533     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1534 )
# -> 1535 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\purav\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_base_client.py:1194, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1191     if not response.is_closed:
#    1192         response.read()
# -> 1194     raise self._make_status_error_from_response(response) from None
#    1196 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.4: user messages must have non-empty content'}, 'request_id': 'req_011Cc6ZnyTDqRdPzpjYHKHYU'}
